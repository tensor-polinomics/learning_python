# %%
# %run -i "../util/util_simple_classifier.ipynb"

# %%
from langdetect import detect # detect language
from nltk import word_tokenize # word tokenizer
from nltk.probability import FreqDist # frequency distribution
from nltk.corpus import stopwords # stopwords
from string import punctuation # punctuation characters

# %%
(train_df, test_df) = load_train_test_dataset_pd("train", "test")
print(train_df.head())
print(test_df.head())
# Out:
#                                                 text  label
# 0  the rock is destined to be the 21st century's ...      1
# 1  the gorgeously elaborate continuation of " the...      1
# 2                     effective but too-tepid biopic      1
# 3  if you sometimes like to go to the movies to h...      1
# 4  emerges as something rare , an issue movie tha...      1
#                                                 text  label
# 0  lovingly photographed in the manner of a golde...      1
# 1              consistently clever and suspenseful .      1
# 2  it's like a " big chill " reunion of the baade...      1
# 3  the story gives ample opportunity for large-sc...      1
# 4                  red dragon " never cuts corners .      1

# %%
# Filter out non-English reviews
print(len(train_df))
train_df["lang"] = train_df["text"].apply(detect)
train_df = train_df[train_df["lang"] == "en"]
print(len(train_df))
# Out:
# 8530
# 8350

# %%
test_df["lang"] = test_df["text"].apply(detect)
test_df = test_df[test_df["lang"] == "en"]

# %%
# Tokenization
train_df["tokenized_text"] = train_df["text"].apply(word_tokenize)
test_df["tokenized_text"] = test_df["text"].apply(word_tokenize)
print(train_df["tokenized_text"].head())
# Out:
# 0    [the, rock, is, destined, to, be, the, 21st, c...
# 1    [the, gorgeously, elaborate, continuation, of,...
# 2                  [effective, but, too-tepid, biopic]
# 3    [if, you, sometimes, like, to, go, to, the, mo...
# 4    [emerges, as, something, rare, ,, an, issue, m...
# Name: tokenized_text, dtype: object

# %%
# Remove stopwords and punctuation
stop_words = list(stopwords.words('english')) + list(punctuation)
stop_words.append("``")
stop_words.append("'s")
def remove_stopwords(x):
    return [word for word in x if word.lower() not in stop_words]
train_df["tokenized_text"] = train_df["tokenized_text"].apply(remove_stopwords)
test_df["tokenized_text"] = test_df["tokenized_text"].apply(remove_stopwords)
print(train_df["tokenized_text"].head())
# Out:
# 0    [rock, destined, 21st, century, new, conan, go...
# 1    [gorgeously, elaborate, continuation, lord, ri...
# 2                       [effective, too-tepid, biopic]
# 3    [sometimes, like, go, movies, fun, wasabi, goo...
# 4    [emerges, something, rare, issue, movie, hones...
# Name: tokenized_text, dtype: object

# %%
# Check label balance
print(train_df.groupby('label').count())
print(test_df.groupby('label').count())
# Out:
#        text  lang  tokenized_text
# label
# 0      4184  4184            4184
# 1      4166  4166            4166
#        text  lang  tokenized_text
# label
# 0       526   526             526
# 1       522   522             522

# %%
# Save cleaned data to disk
# JSON makes your data portable, easy to share, and flexible for future use.
train_df.to_json("../data/rotten_tomatoes_train.json")
test_df.to_json("../data/rotten_tomatoes_test.json")

# %%
# Define a function to extract the most common words from a list of tokenized texts
def get_stats(word_list, num_words=200):
    freq_dist = FreqDist(word_list)
    return freq_dist.most_common(num_words)

# %%
# Compare the most frequent words in positive and negative reviews
# Sum (concatenate) all tokenized words in positive reviews
positive_train_words = train_df[train_df["label"] == 1]["tokenized_text"].sum() 
negative_train_words = train_df[train_df["label"] == 0]["tokenized_text"].sum()
positive_fd = get_stats(positive_train_words, 200)
negative_fd = get_stats(negative_train_words, 200)
print("Most common words in positive reviews:")
print(positive_fd)
# Out:
# Most common words in positive reviews:
# [('film', 684), ('movie', 429), ("n't", 286), ('one', 280), ('--', 271), ('like', 208), ('story', 194), ('comedy', 160), ('good', 150), ('even', 144), ('funny', 137), ('way', 135), ('time', 127), ('best', 126), ('characters', 125), ('make', 124), ('life', 124), ('us', 123), ('much', 122), ('love', 118), ('performances', 117), ('makes', 115), ('may', 113), ('work', 111), ('director', 110), ('enough', 105), ('look', 103), ('still', 96), ('little', 94), ('well', 93), ('new', 92), ('films', 92), ('movies', 89), ('fun', 89), ('great', 88), ('drama', 87), ('two', 85), ('performance', 82), ('never', 81), ('could', 80), ('see', 77), ('world', 77), ('people', 76), ('cast', 75), ('many', 74), ('also', 73), ('though', 73), ('tale', 71), ('first', 70), ('documentary', 69), ('without', 69), ('entertaining', 68), ('big', 68), ('made', 67), ('heart', 66), ('ever', 65), ('family', 65), ('often', 64), ('would', 64), ('humor', 64), ("'re", 63), ('sense', 63), ('human', 61), ('romantic', 60), ('audience', 60), ('something', 59), ('real', 59), ('american', 59), ('picture', 57), ('cinema', 57), ('yet', 57), ('get', 57), ('take', 56), ('compelling', 56), ('character', 56), ('really', 55), ('thriller', 55), ('far', 53), ('works', 53), ('year', 53), ('kind', 53), ('man', 53), ("'ll", 53), ('worth', 52), ('might', 52), ('every', 51), ('music', 50), ('better', 50), ('gives', 50), ('moving', 50), ('full', 50), ('plot', 50), ('fascinating', 49), ('seen', 49), ('long', 48), ('right', 48), ('moments', 48), ('hollywood', 48), ('always', 47), ('screen', 47), ('part', 47), ('young', 47), ('takes', 47), ('feel', 46), ('interesting', 46), ('history', 45), ('times', 44), ('piece', 44), ('experience', 43), ('quite', 43), ('portrait', 43), ('watching', 42), ('manages', 42), ('another', 42), ('want', 41), ('lot', 41), ('bit', 41), ('emotional', 41), ('years', 40), ('sweet', 40), ('go', 39), ('comes', 39), ('give', 39), ('smart', 39), ('almost', 39), ('less', 39), ('original', 39), ('enjoyable', 39), ('solid', 39), ('despite', 39), ('ultimately', 38), ('kids', 38), ('ca', 38), ('beautiful', 38), ('action', 38), ('nothing', 38), ('cinematic', 38), ('keep', 38), ('seems', 38), ("'ve", 38), ('offers', 37), ('culture', 37), ('old', 37), ('together', 37), ('back', 37), ('scenes', 37), ('touching', 37), ('women', 37), ('mr', 36), ('script', 36), ('come', 36), ('rare', 35), ('charming', 35), ('charm', 35), ('intelligent', 35), ('rather', 35), ('acting', 35), ('power', 35), ('find', 35), ('end', 35), ('delivers', 35), ('entertainment', 34), ('gets', 34), ('powerful', 34), ('hard', 34), ('fans', 34), ('sometimes', 33), ('true', 33), ('actors', 33), ('engaging', 33), ('art', 33), ('whose', 33), ('away', 32), ('know', 32), ('beautifully', 32), ('perfect', 32), ('face', 32), ('subject', 32), ('fine', 32), ('thing', 32), ('study', 32), ('surprisingly', 32), ('going', 31), ('lives', 31), ('think', 31), ('since', 31), ('journey', 31), ('watch', 31), ('style', 31), ('genre', 31), ('terrific', 31), ('least', 31), ('minutes', 30), ('say', 30), ('hilarious', 30), ('french', 30), ('dark', 30), ('making', 29), ('deeply', 29), ('visual', 29)]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import classification_report

# %%
# Load JSON files
train_df = pd.read_json("../data/rotten_tomatoes_train.json")
test_df = pd.read_json("../data/rotten_tomatoes_test.json")

# %%
train_df.head()
# Out:
#                                                 text  label lang  \
# 0  the rock is destined to be the 21st century's ...      1   en
# 1  the gorgeously elaborate continuation of " the...      1   en
# 2                     effective but too-tepid biopic      1   en
# 3  if you sometimes like to go to the movies to h...      1   en
# 4  emerges as something rare , an issue movie tha...      1   en
#
#                                       tokenized_text
# 0  [rock, destined, 21st, century, new, conan, go...
# 1  [gorgeously, elaborate, continuation, lord, ri...
# 2                     [effective, too-tepid, biopic]
# 3  [sometimes, like, go, movies, fun, wasabi, goo...
# 4  [emerges, something, rare, issue, movie, hones...

# %%
len(train_df), len(test_df)
# Out:
# (8350, 1048)

# %%
# Raw text version (without vectorization) of positive and negative reviews
positive_train_words = train_df[train_df["label"] == 1].tokenized_text.sum()
negative_train_words = train_df[train_df["label"] == 0].tokenized_text.sum()
word_intersection = set(positive_train_words) & set(negative_train_words)
positive_filtered = list(set(positive_train_words) - word_intersection)
negative_filtered = list(set(negative_train_words) - word_intersection)

# %%
len(positive_filtered), len(negative_filtered)
# Out:
# (5486, 5977)

# %%
positive_filtered
# Out:
# ["'blue",
#  'creep',
#  'dwarfs',
#  'milestone',
#  'embers',
#  'onstage',
#  'confronted',
#  'jeff',
#  'tully',
#  'substances',
#  'low-down',
#  'bigotry',
#  'intently',
#  'annoyances',
#  'fore',
#  'herbivore',
#  'telescope',
#  'rise-and-fall',
#  'usurp',
#  'satisfyingly',
#  'polson',
#  'quotient',
#  'cahill',
#  'gerbosi',
#  "'laugh",
#  'prefer',
#  'optimistic',
#  'divisions',
#  'speeds/',
#  'locals',
#  'tact',
#  'exposure',
#  'effusion',
#  'worship',
#  'temptations',
#  'fury',
#  'homosexuality',
#  'foreboding',
#  'fosters',
#  'illustrating',
#  'fillm',
#  'rapt',
#  'whipping',
#  'melted',
#  'judicious',
#  'mending',
#  'sanders',
#  'overt',
#  'supportive',
#  'excites',
#  'flames',
#  'illustrated',
#  'wiseman',
#  'disregard',
#  'avis',
#  'natural-seeming',
#  'bellini',
#  'households',
#  'swiftly',
#  'dared',
#  'scandals',
#  'imparted',
#  'holistic',
#  'coral',
#  'steadily',
#  'withering',
#  'wen',
#  'dude',
#  'fiascoes',
#  'merrily',
#  'canadians',
#  'relief',
#  'lately',
#  'painterly',
#  'model',
#  'junior-high',
#  'seacoast',
#  'small-scale',
#  'aristocratic',
#  'retaliatory',
#  'dallas',
#  'amassed',
#  'tar',
#  'successfully',
#  'wire',
#  'reenactment',
#  'forefront',
#  'wallflower',
#  'oppressive',
#  'graduation',
#  'clashing',
#  'wrenching',
#  'melds',
#  'worldly-wise',
#  'persistence',
#  'often-hilarious',
#  'image',
#  'appétit',
#  'lapaglia',
#  'krige',
#  'morph',
#  'areas',
#  'non-disney',
#  'confirmation',
#  'dench',
#  'german',
#  'shellshock',
#  "'very",
#  'watts',
#  'macnaughton',
#  'utilized',
#  'crowdpleaser',
#  '179-minute',
#  'off-the-cuff',
#  'nicole',
#  'blunder',
#  'kid-empowerment',
#  'implicitly',
#  'falcon',
#  'restrictive',
#  'sweet-tempered',
#  'observed',
#  'wondered',
#  'ilya',
#  'bludgeoning',
#  'kinetically-charged',
#  'indictment',
#  'on-board',
#  'insane',
#  'impulsive',
#  'uncanny',
#  'activities',
#  'survivors',
#  'unsubtle',
#  'maggots',
#  'kozmo',
#  'revigorates',
#  'nakedness',
#  'navel-gazing',
#  "'suits",
#  'freshening',
#  'triple',
#  "'silence",
#  'slice-of-depression',
#  'boom-bam',
#  'jazzes',
#  'bend',
#  'daniel',
#  'purer',
#  'obsessive-compulsive',
#  'alexandre',
#  'neglecting',
#  'm-16',
#  'eats',
#  'speech',
#  'brew',
#  'sickness',
#  'confrontations',
#  'gleefully',
#  'averting',
#  'darling',
#  'homes',
#  'stuffiest',
#  'ilk',
#  'soda',
#  'spangle',
#  'aisles',
#  'placid',
#  'finesse',
#  'deceivingly',
#  'charred',
#  'environments',
#  'kouyate',
#  'dave',
#  'slump',
#  'bombay',
#  'kindred',
#  '-after',
#  'encompasses',
#  'atmospheric',
#  'carlos',
#  'brecht',
#  'bastions',
#  'forgoes',
#  'rigged',
#  'friel',
#  'lewis',
#  'patois',
#  'fetishes',
#  'duration',
#  'docu-makers',
#  'anchoring',
#  'blacklight',
#  'bromides',
#  'deceptive',
#  'disgusted',
#  'racism',
#  'hunnam',
#  'saigon',
#  'goya',
#  'flurries',
#  'bishop',
#  'knowingly',
#  'erects',
#  'tanovic',
#  'self-actualization',
#  'intolerance',
#  'iconography',
#  'establishes',
#  'belittle',
#  'charmingly',
#  'chess',
#  'teeth-clenching',
#  'picking',
#  'sugar-sweet',
#  'hippies',
#  'minefield',
#  'hatfield',
#  'cherished',
#  'shoes',
#  'taxi',
#  'mordant',
#  'proceed',
#  'ramifications',
#  'sl2',
#  'best-known',
#  'desolate',
#  'humanitarian',
#  'sublime',
#  'compulsive',
#  'unnerve',
#  'movingly',
#  'trials',
#  'democracies',
#  'nerve-rattling',
#  '-a',
#  'cliché-riddled',
#  'vietnam',
#  'parris',
#  'jazzy',
#  'bluer',
#  'striving',
#  'emphasized',
#  'eyeball-to-eyeball',
#  'armageddon',
#  'skilled',
#  'fountainheads',
#  'cope',
#  'superbly',
#  'reassuring',
#  'instability',
#  'dicaprio',
#  'maverick',
#  'routes',
#  'enthuse',
#  'undemanding',
#  'ensnared',
#  'well-observed',
#  'discontent',
#  'lending',
#  'easygoing',
#  'time-wasting',
#  'arliss',
#  'dishonesty',
#  'wittier',
#  'goo',
#  'visitor',
#  'merges',
#  'swashbuckling',
#  'overdose',
#  'clicking',
#  'wherever',
#  'gesture',
#  'conan',
#  'horror/thriller',
#  'engulfed',
#  'sprouts',
#  'crit',
#  'northwest',
#  'transcendence',
#  'rainbow',
#  'tics',
#  'malnourished',
#  'axel',
#  'aesthetically',
#  '78',
#  'mischievous',
#  'rawness',
#  'exhausted',
#  'statecraft',
#  'hitler-study',
#  'relaxed',
#  'quietness',
#  'configurations',
#  'brittle',
#  'immortal',
#  'unassuming',
#  'tantalizes',
#  'departments',
#  'tomorrow',
#  'revolutionaries',
#  "'film",
#  'fatalist',
#  'co-star',
#  'hit-man',
#  'professes',
#  'collegiate',
#  'mar',
#  'glitches',
#  'unafraid',
#  'naiveté',
#  'senseless',
#  'goofiest',
#  'latches',
#  'lively',
#  'schütte',
#  'freewheeling',
#  'self-hating',
#  'self-centered',
#  'girl-',
#  'heck',
#  'layered',
#  'tracts',
#  'ache',
#  'anti-semitism',
#  'fashioned',
#  'keenest',
#  'amongst',
#  'hatosy',
#  'dished',
#  'pulsating',
#  'hard-won',
#  'resuscitate',
#  'forgiveness',
#  'chortles',
#  'ramble',
#  'nauseating',
#  'russian',
#  'unexpectedly',
#  'kurdish',
#  'rebirth',
#  'punk',
#  'nia',
#  'kings',
#  'metaphorical',
#  're-enactments',
#  'thoughtfully',
#  'gaï',
#  'architectural',
#  'plateau',
#  'stylistic',
#  'clara',
#  'staggered',
#  'corruption',
#  'wham-bam',
#  'avert',
#  'examine',
#  'inventively',
#  'vigils',
#  'embroils',
#  'tremble',
#  'middle-fingered',
#  'weaving',
#  'insistence',
#  'orc',
#  'miraculous',
#  'tricky',
#  'dubya',
#  'grown',
#  'liberation',
#  'anti-hollywood',
#  'penn',
#  'straight-up',
#  'evocation',
#  'powaqqatsi',
#  'two-lane',
#  'razor-sided',
#  'seesawed',
#  'mexico',
#  'trinity',
#  'social/economic/urban',
#  'crooning',
#  'conquer',
#  'slam-bang',
#  'crippled',
#  'petter',
#  "'nicholas",
#  'toes',
#  'beseechingly',
#  'psychic',
#  'well-deserved',
#  'arcane',
#  'desires',
#  'peddled',
#  'highway',
#  'distinct',
#  'idolized',
#  'counts',
#  'artless',
#  'nerve-wracking',
#  '\x91direct-to-video',
#  'stylist',
#  'exterminator',
#  'firth',
#  'differences',
#  'espn',
#  'wise-beyond-her-years',
#  'dogma-like',
#  'norm',
#  'sexiness',
#  'thi',
#  'conjuring',
#  'volletta',
#  'contradictions',
#  'fraught',
#  'sydow',
#  're-release',
#  'spike',
#  'casings',
#  'consistency',
#  'mood-altering',
#  'badge',
#  'browning',
#  'weimar',
#  'survival',
#  'fontaine',
#  'sublimely',
#  'hard-hitting',
#  'spielbergian',
#  'repetitious',
#  'deckhand',
#  'hypocrisies',
#  'devilishly',
#  'lethargic',
#  'tunisian',
#  'wryly',
#  'whit',
#  'zinger-filled',
#  'satisfies',
#  'lightest',
#  'ethnicities',
#  'accident-prone',
#  'ackerman',
#  'bind',
#  'biggie',
#  'martinet',
#  'emphatic',
#  'expanse',
#  'compass',
#  'bullseye',
#  'unleashed',
#  'creamy',
#  'harbor',
#  'depending',
#  'reenacting',
#  'tragically',
#  'adolescence',
#  'president',
#  'gelati',
#  'hyperbole',
#  'whippersnappers',
#  'prepare',
#  'rail',
#  'spader',
#  'griffith',
#  'banking',
#  'unknowable',
#  'political-action',
#  'herek',
#  'dumbo',
#  '270',
#  'specialty',
#  'ikea',
#  'isabelle',
#  'brush',
#  'resonates',
#  'multilayered',
#  'traces',
#  'finishes',
#  'parsec',
#  'craftsmen',
#  'fantasy-adventure',
#  'english-language',
#  'one-shot',
#  'tarantula',
#  'turpin',
#  'intuitively',
#  'musclefest',
#  'wounded',
#  'majidi',
#  'undogmatic',
#  'snags',
#  'from-television',
#  'octopus',
#  'all-french',
#  'stumblings',
#  'monica',
#  'consume',
#  'undertaking',
#  'confirming',
#  'overflows',
#  'over-amorous',
#  "'chops",
#  'probes',
#  'rarest',
#  'coastal',
#  'telemarketers',
#  'stooges',
#  'jeong',
#  'invokes',
#  'innovations',
#  'challenging',
#  'laws',
#  'irrelevancy',
#  'scriptwriters',
#  'gored',
#  'uncompromising',
#  'besco',
#  'stunned',
#  'alacrity',
#  'bargain',
#  'calories',
#  'depression',
#  'blacked',
#  'slavery',
#  'teary-eyed',
#  'narcotized',
#  'ideally',
#  '129-minute',
#  'ripper',
#  'subtleties',
#  'cold-blooded',
#  'questioning',
#  'payback',
#  'socio-political',
#  'preposterousness',
#  'dreamy',
#  'narcotics',
#  'hitch',
#  'tori',
#  'transparency',
#  'quills',
#  'robberies',
#  'recalls',
#  'marrow',
#  'potemkin',
#  'decibel',
#  '-the-night',
#  'subjective',
#  'flesh',
#  'drops',
#  'collaborative',
#  'disarming',
#  'pitted',
#  'taps',
#  'howlingly',
#  'multi-layered',
#  'ideology',
#  'judging',
#  'pompeo',
#  'play-doh',
#  'matron',
#  'desplat',
#  'sidesteps',
#  'tavernier',
#  'integrity',
#  'vocalized',
#  'multi-layers',
#  'ignite',
#  'seaside',
#  'kooky',
#  'careworn',
#  'deutchland',
#  'indulgently',
#  'tingle',
#  'ages',
#  'potent',
#  'reliable',
#  'interpersonal',
#  'channel-style',
#  'hue',
#  'all-around',
#  'towers',
#  'urgently',
#  'chronic',
#  'dexterous',
#  'ideals',
#  'locked',
#  'discursive',
#  'paths',
#  're-assess',
#  'zhuangzhuang',
#  'presumption',
#  'ever-escalating',
#  'documentaries',
#  'griffiths',
#  'intensifying',
#  'calm',
#  'raft',
#  'israeli-occupied',
#  'outselling',
#  'carion',
#  'koury',
#  'enigmatic',
#  'chanting',
#  'pertinent',
#  'rigorously',
#  'sickeningly',
#  'roaring',
#  'flinching',
#  'distaste',
#  'assumption',
#  'chaos',
#  'perceptively',
#  'fret',
#  'mullan',
#  'youngster',
#  'memory-as-identity',
#  'samantha',
#  'strict',
#  'shell',
#  'dedicated',
#  'sturdy',
#  'dreamworks',
#  'affectation-free',
#  'kinetic',
#  'combustible',
#  'sophomore',
#  'homework',
#  'co-winner',
#  'princesses',
#  'inventing',
#  'ruggero',
#  'reflecting',
#  'in-depth',
#  'aground',
#  'perversity',
#  'input',
#  'communicate',
#  'valiant',
#  'believed',
#  'westfeldt',
#  'gyllenhaal',
#  'featherweight',
#  'yell',
#  'christelle',
#  'snazziness',
#  'recasts',
#  'pastel',
#  'super-sized',
#  'cop-flick',
#  'maids',
#  'benoit',
#  'münch',
#  'indomitable',
#  'kid-pleasing',
#  'arresting',
#  'fairytale',
#  'literate',
#  '77-minute',
#  "'stoked",
#  'stakes',
#  'instructor',
#  'gamble',
#  'jealousy',
#  'naomi',
#  'subtlest',
#  'well-detailed',
#  'reclaiming',
#  'hallucinatory',
#  'arena',
#  'enlightened',
#  '6-year-old',
#  'bernal',
#  'superlative',
#  'controversial',
#  'idealism',
#  'optic',
#  '2-d',
#  'reconstruction',
#  'articulate',
#  'maturity',
#  'downy-cheeked',
#  'deflated',
#  'admitting',
#  'excel',
#  'rope',
#  '11-year-old',
#  'varying',
#  'rival',
#  'sappier',
#  'wladyslaw',
#  'jam',
#  'retrospectively',
#  'touchingly',
#  'bowling',
#  'ego',
#  '82',
#  'sip',
#  'recessive',
#  'biologically',
#  'dazzlingly',
#  'ziyi',
#  'futures',
#  'glancing',
#  'elegiac',
#  'grieving',
#  'reconfigured',
#  'unit',
#  'statesmen',
#  'realistically',
#  'spoofs',
#  'pentacostal',
#  'alexander',
#  'bristles',
#  'papin',
#  'verite',
#  'introduces',
#  'martinez',
#  'exuberant',
#  'sisterly',
#  'smartly',
#  'juggling',
#  'seduced',
#  'biennial',
#  'conspirators',
#  'caffeinated',
#  'defoliation',
#  'cursory',
#  'heart-wrenching',
#  'b-scene',
#  'dreyfus',
#  'bedfellows',
#  'pad',
#  'humankind',
#  'riveted',
#  'nuance',
#  'unsettlingly',
#  'skeletons',
#  'fi',
#  'sadists',
#  'tantalizing',
#  'super-dooper-adorability',
#  'warmly',
#  'representing',
#  'cribbed',
#  'bombshell',
#  'good-time',
#  'mid-seventies',
#  'french-produced',
#  'heller',
#  'prescription',
#  'lacerating',
#  'gullible',
#  'befuddlement',
#  'pop-cyber',
#  'nightclub',
#  'figurative',
#  'crave',
#  'ayres',
#  'winningly',
#  'notches',
#  'marathons',
#  'changer',
#  'composition',
#  '2/3',
#  'unnoticed',
#  'wines',
#  'bravely',
#  'technology-of-the-moment',
#  'lecherous',
#  'backstory',
#  'glinting',
#  'accomodates',
#  'eye-opening',
#  'isolation',
#  'orthodox',
#  'venomous',
#  'doggedness',
#  'heart-stopping',
#  'afghan',
#  'sweating',
#  'ravel',
#  'channeling',
#  'nietzsche-referencing',
#  'vardalos',
#  'meeropol',
#  'modicum',
#  'testify',
#  'all-american',
#  'shoestring',
#  'extensions',
#  'curlers',
#  'tu',
#  'angelina',
#  'off-season',
#  'unreachable',
#  'fighter',
#  'owners',
#  'aggressiveness',
#  'connect-the-dots',
#  'forwards',
#  'dysfunction',
#  'fizzability',
#  'mesh',
#  'baran',
#  'aching',
#  'ethereal',
#  'set-piece',
#  'secretly',
#  'dunst',
#  'debuter',
#  'nakata',
#  'trade',
#  'shrugging',
#  'transporting',
#  'less-',
#  'whence',
#  'imperfection',
#  '1999',
#  'shifty',
#  'smack',
#  'star-power',
#  'explores',
#  'flakeball',
#  'payne',
#  'spectacles',
#  'ladles',
#  'viewings',
#  'backstabbing',
#  'dissidents',
#  'pee-related',
#  'slipperiness',
#  'sacrifice',
#  'snowballs',
#  'worm',
#  'horror-comedy',
#  'brethren',
#  'lore',
#  'uk',
#  'a-list',
#  'ghostbusters',
#  'lucía',
#  'bermuda',
#  'hyper-realistic',
#  'cary',
#  'sydney',
#  'weakened',
#  'vary',
#  'passer',
#  'ellie',
#  'boundary-hopping',
#  'commerce',
#  'joins',
#  'matter-of-fact',
#  'hellstenius',
#  'mesmerize',
#  'interference',
#  'strap',
#  'risks',
#  'pearl',
#  'terrorizing',
#  'idoosyncratic',
#  'playfully',
#  'capability',
#  'influential',
#  'transitions',
#  'tooled',
#  'gaza',
#  'unconned',
#  'smiling',
#  'articulates',
#  'plaintiveness',
#  'well-edited',
#  'bone-dry',
#  'girl-meets-girl',
#  'myths',
#  'hardscrabble',
#  'dismember',
#  'bias',
#  'wounds',
#  'bar-scrapping',
#  'splat-man',
#  'introverted',
#  'self-destructive',
#  'no-holds-barred',
#  'binds',
#  'spiral',
#  "'my",
#  'repression',
#  'giggle-inducing',
#  'tape',
#  'hopeful',
#  'anchors',
#  'accident',
#  'visionary',
#  'requiring',
#  'meddles',
#  'dormer',
#  'partially',
#  'rapids',
#  'exuberantly',
#  'tissues',
#  'magnify',
#  'eudora',
#  'spans',
#  'feminine',
#  'declared',
#  'quantum',
#  'entrancing',
#  'rudy',
#  'blanchett',
#  'mullinski',
#  'near-disaster',
#  'reinforces',
#  'anarchist',
#  'irritates',
#  'defiantly',
#  'inspection',
#  'occurrences',
#  'casey',
#  'impartiality',
#  'dabbling',
#  'guzmán',
#  'higher',
#  'fluidly',
#  'peppering',
#  'all-in-all',
#  'twohy',
#  'inhospitability',
#  'embedded',
#  'offended',
#  'crime-land',
#  'abundantly',
#  'bedevilling',
#  'catalyst',
#  'undiscovered',
#  'economy',
#  'strikingly',
#  'self-aggrandizing',
#  'continued',
#  'carrera',
#  'a-bornin',
#  'cynics',
#  'mindsets',
#  'shape-shifting',
#  'representations',
#  'reminder',
#  'inscrutable',
#  'sympathetically',
#  'fantasia',
#  'skateboarding',
#  'cassel',
#  'invitation',
#  'meat-and-potatoes',
#  'madame',
#  'upfront',
#  'philibert',
#  'astoundingly',
#  'happiest',
#  'adroitly',
#  'environs',
#  'blasts',
#  'distancing',
#  'plainness',
#  'craving',
#  'indulging',
#  'harbour',
#  'mainland',
#  'accumulates',
#  'tea',
#  '20-year-old',
#  'composing',
#  'artifacts',
#  "'de",
#  'paranoid',
#  'saucer-eyed',
#  'pearce',
#  'redux',
#  'nations',
#  'mass-market',
#  'gasp',
#  'misfits',
#  'beresford',
#  'flops',
#  'wisegirls',
#  'specimen',
#  'helpings',
#  'jacked-up',
#  'non-threatening',
#  'confounding',
#  'skillful',
#  'pornography',
#  'buzz-obsessed',
#  'gaiety',
#  'sociologically',
#  'kindness',
#  'machinery',
#  'millennial',
#  'christianity',
#  ...]

# %%
# Vectorizer function
def create_vectorizers(word_lists):
    vectorizers = []
    for word_list in word_lists:
        vectorizer = CountVectorizer(vocabulary=word_list)
        vectorizers.append(vectorizer)
    return vectorizers

# %%
vectorizers = create_vectorizers([positive_filtered, negative_filtered])

# %%
# Defines a function to count words from different vocabularies in a tokenized text.
def vectorize(text_list, vectorizers):
    # text_list: list of tokens
    # vectorizers: list of fitted CountVectorizer objects
    text = " ".join(text_list) # joint the list of tokens into a space-separated string
    scores = [] # list of scores from each vectorizer
    for vectorizer in vectorizers:
        output = vectorizer.transform([text]) # sparse matrix (1,, n_vocab)
        output_sum = sum(output.todense().tolist()[0])
        scores.append(output_sum)
    return scores # total number of matched words from each vectorizer

# %%
# Simple classification rule based on the highest score
def classify(score_list):
    return max(enumerate(score_list), key=lambda x: x[1])[0]

# %%
train_df["prediction"] = train_df["tokenized_text"].apply(lambda x: classify(vectorize(x, vectorizers)))
test_df["prediction"] = test_df["tokenized_text"].apply(lambda x: classify(vectorize(x, vectorizers)))

# %%
train_df.head()
# Out:
#                                                 text  label lang  \
# 0  the rock is destined to be the 21st century's ...      1   en
# 1  the gorgeously elaborate continuation of " the...      1   en
# 2                     effective but too-tepid biopic      1   en
# 3  if you sometimes like to go to the movies to h...      1   en
# 4  emerges as something rare , an issue movie tha...      1   en
#
#                                       tokenized_text  prediction
# 0  [rock, destined, 21st, century, new, conan, go...           0
# 1  [gorgeously, elaborate, continuation, lord, ri...           0
# 2                     [effective, too-tepid, biopic]           0
# 3  [sometimes, like, go, movies, fun, wasabi, goo...           0
# 4  [emerges, something, rare, issue, movie, hones...           0

# %%
print(classification_report(train_df["label"], train_df["prediction"]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.19      0.23      0.21      4184
#            1       0.01      0.01      0.01      4166
#
#     accuracy                           0.12      8350
#    macro avg       0.10      0.12      0.11      8350
# weighted avg       0.10      0.12      0.11      8350

# %%
print(classification_report(test_df["label"], test_df["prediction"]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.56      0.47       526
#            1       0.27      0.16      0.20       522
#
#     accuracy                           0.36      1048
#    macro avg       0.34      0.36      0.34      1048
# weighted avg       0.34      0.36      0.34      1048
